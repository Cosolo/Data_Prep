# %%
# Data Quality report


import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Data/gradedata.csv')

# %%
data.mode().transpose()
# Out:
#                                        0     \
# fname                                 Dolan
# lname                                Conley
# gender                               female
# age                                      17
# exercise                                  4
# hours                                    11
# grade                                   100
# address   1 Chapel Ave., Cheshire, CT 06410
#
#                                            1     \
# fname                                       NaN
# lname                                    Harvey
# gender                                     male
# age                                         NaN
# exercise                                    NaN
# hours                                       NaN
# grade                                       NaN
# address   1 Cottage Street, Rockville, MD 20850
#
#                                          2     \
# fname                                     NaN
# ...

# %%
data.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %% [markdown]
# Find data type of each column

# %%
data_types=pd.DataFrame(data.dtypes, columns=['Data Type'])
data_types
# Out:
#          Data Type
# fname       object
# lname       object
# gender      object
# age          int64
# exercise     int64
# hours        int64
# grade      float64
# address     object

# %%
data.dtypes
# Out:
# fname        object
# lname        object
# gender       object
# age           int64
# exercise      int64
# hours         int64
# grade       float64
# address      object
# dtype: object

# %% [markdown]
# Count number of missing values

# %%
data.isnull().sum()
# Out:
# fname       0
# lname       0
# gender      0
# age         0
# exercise    0
# hours       0
# grade       0
# address     0
# dtype: int64

# %%
missing_data_counts=pd.DataFrame(data.isnull().sum(), columns=['Missing Values'])
missing_data_counts
# Out:
#           Missing Values
# fname                  0
# lname                  0
# gender                 0
# age                    0
# exercise               0
# hours                  0
# grade                  0
# address                0

# %% [markdown]
# Count number of present observations by column

# %%
present_data_count=pd.DataFrame(data.count(), columns=['Present values'])

# %%
# min value of each column

# %%
min_values=pd.DataFrame(columns=['Min values'])
for v in list (data.columns.values):
    min_values.loc[v]=[data[v].min()]
min_values
# Out:
#                                  Min values
# fname                                 Aaron
# lname                               Acevedo
# gender                               female
# age                                      14
# exercise                                  0
# hours                                     0
# grade                                    32
# address   1 Chapel Ave., Cheshire, CT 06410

# %%
max_values=pd.DataFrame(columns=['Min values'])
for v in list (data.columns.values):
    max_values.loc[v]=[data[v].max()]
max_values
# Out:
#                                     Min values
# fname                                   Zorita
# lname                                Zimmerman
# gender                                    male
# age                                         19
# exercise                                     5
# hours                                       20
# grade                                      100
# address   9999 Longbranch St., Wayne, NJ 07470

# %%
#join all data into one table

# %%
pd.concat([present_data_count,missing_data_counts,max_values,min_values], axis=1)
# Out:
#           Present values  Missing Values  \
# fname               2000               0
# lname               2000               0
# gender              2000               0
# age                 2000               0
# exercise            2000               0
# hours               2000               0
# grade               2000               0
# address             2000               0
#
#                                     Min values  \
# fname                                   Zorita
# lname                                Zimmerman
# gender                                    male
# age                                         19
# exercise                                     5
# hours                                       20
# grade                                      100
# address   9999 Longbranch St., Wayne, NJ 07470
#
#                                  Min values
# fname                                 Aaron
# lname                               Acevedo
# ...

# %%
data.hist(column='hours', by='gender')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002370F8663C8>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(data.index, data['hours'])

# %%
plt.scatter(data.index, data['grade'])
